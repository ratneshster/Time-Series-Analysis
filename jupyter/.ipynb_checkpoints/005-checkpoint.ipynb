# %%
# Import dependencies
import os, gdax, collections
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import *
import statsmodels.api as sm
from itertools import izip, count

# %%
# Public Client from GDAX Bitcoin Exchange
public_client = gdax.PublicClient()

# %%
# Get all products available
products = pd.DataFrame(public_client.get_products())

# %%
# Display products
products
# Out:
#   base_currency base_max_size base_min_size display_name       id  \
# 0           LTC       1000000          0.01      LTC/EUR  LTC-EUR
# 1           LTC       1000000          0.01      LTC/BTC  LTC-BTC
# 2           LTC       1000000          0.01      LTC/USD  LTC-USD
# 3           ETH          5000          0.01      ETH/USD  ETH-USD
# 4           ETH          5000          0.01      ETH/EUR  ETH-EUR
# 5           ETH          5000          0.01      ETH/BTC  ETH-BTC
# 6           BTC           250          0.01      BTC/USD  BTC-USD
# 7           BTC           250          0.01      BTC/EUR  BTC-EUR
# 8           BTC           250          0.01      BTC/GBP  BTC-GBP
#
#   margin_enabled quote_currency quote_increment
# 0          False            EUR            0.01
# 1          False            BTC         0.00001
# 2          False            USD            0.01
# 3          False            USD            0.01
# 4          False            EUR            0.01
# 5          False            BTC         0.00001
# 6          False            USD            0.01
# 7          False            EUR            0.01
# 8          False            GBP            0.01

# %%
public_client.get_product_ticker(product_id='BTC-EUR')
public_client.get_product_24hr_stats('ETH-EUR')
public_client.get_product_historic_rates('ETH-EUR')
public_client.get_product_historic_rates('BTC-EUR')
# Out:
# [[1509539160, 5680.02, 5685.34, 5683.69, 5685.34, 3.2576223300000002],
#  [1509539100, 5669.99, 5685.34, 5670, 5685.34, 4.333209679999999],
#  [1509539040, 5665, 5700.01, 5700.01, 5670, 17.991620899999994],
#  [1509538980, 5700.01, 5720.01, 5720.01, 5700.02, 8.12196894],
#  [1509538920, 5720, 5720.98, 5720.98, 5720.01, 4.539193490000001],
#  [1509538860, 5720.98, 5720.98, 5720.98, 5720.98, 1.03402023],
#  [1509538800, 5717.64, 5724.98, 5718.92, 5720.98, 4.250905649999999],
#  [1509538740, 5715.1, 5719.4, 5719.31, 5718.98, 1.5660990600000002],
#  [1509538680, 5715.05, 5719.31, 5719, 5719.31, 5.659470899999999],
#  [1509538620, 5710, 5720, 5715.18, 5719.06, 9.306996739999999],
#  [1509538560, 5715, 5720.31, 5720.31, 5715.99, 6.785498739999998],
#  [1509538500, 5719.1, 5722.69, 5720.01, 5720.31, 3.10192145],
#  [1509538440, 5719.1, 5726.21, 5726.17, 5722.47, 10.442424699999998],
#  [1509538380, 5720, 5726.21, 5722.01, 5726.21, 5.6297708],
#  [1509538320, 5721.57, 5731.63, 5727.1, 5724.25, 5.450893769999997],
#  [1509538260, 5721.57, 5732.99, 5732.99, 5727.22, 8.146015889999994],
#  [1509538200, 5731.01, 5749.78, 5740, 5733.31, 14.962482269999994],
#  [1509538140, 5740, 5750.95, 5750.95, 5740, 7.427850619999997],
#  [1509538080, 5742.01, 5756.5, 5756.31, 5742.01, 9.908443449999993],
#  [1509538020, 5756, 5758.88, 5758.87, 5756.35, 6.662792519999998],
#  [1509537960, 5758.2, 5762, 5758.21, 5758.38, 8.88249465],
#  [1509516960, 5568.01, 5568.01, 5568.01, 5568.01, 0.7100000000000001],
#  [1509516900, 5568.01, 5568.01, 5568.01, 5568.01, 0.12],
#  [1509516840, 5568, 5568.01, 5568.01, 5568, 0.9730000000000001],
#  [1509516780, 5568.01, 5568.06, 5568.06, 5568.01, 0.33896734],
#  [1509516720, 5568.05, 5568.06, 5568.06, 5568.06, 1.63],
#  [1509516660, 5568.05, 5568.05, 5568.05, 5568.05, 0.03],
#  [1509516600, 5568.05, 5568.06, 5568.05, 5568.06, 0.13999999999999999],
#  [1509516540, 5568.05, 5568.06, 5568.06, 5568.05, 0.2],
#  [1509516480, 5568.05, 5568.06, 5568.06, 5568.05, 0.46044042999999996],
#  [1509516420, 5568.09, 5573.46, 5573.46, 5568.09, 1.10532307],
#  [1509516360, 5575.07, 5575.2, 5575.07, 5575.2, 0.12],
#  [1509516300, 5568.22, 5575.6, 5573.92, 5568.22, 0.19],
#  [1509516240, 5566.46, 5566.72, 5566.72, 5566.46, 0.24000000000000002],
#  [1509516120, 5571.16, 5577.96, 5572.49, 5571.16, 0.07999999999999999],
#  [1509516060, 5563.68, 5578, 5566.17, 5564.92, 0.5921108800000001],
#  [1509516000, 5563.67, 5568.49, 5568.49, 5565.48, 0.10179192],
#  [1509515940, 5566.63, 5571.61, 5571.61, 5571.61, 0.38000000000000006],
#  [1509515880, 5572.26, 5578.25, 5578.25, 5572.26, 1.92909236],
#  [1509515820, 5578.25, 5578.25, 5578.25, 5578.25, 0.23000000000000004],
#  [1509515760, 5578.25, 5578.25, 5578.25, 5578.25, 0.06],
#  [1509515700, 5578.25, 5578.25, 5578.25, 5578.25, 0.4800000000000001],
#  [1509515640, 5578.24, 5578.25, 5578.25, 5578.25, 0.26],
#  [1509515580, 5578.25, 5578.25, 5578.25, 5578.25, 0.48],
#  [1509515520, 5578.14, 5590, 5578.14, 5578.25, 1.3],
#  [1509515460, 5558.19, 5590, 5558.19, 5590, 1.6500000000000001],
#  [1509515400, 5558.18, 5558.19, 5558.19, 5558.19, 0.54893203],
#  [1509515340, 5558.19, 5558.19, 5558.19, 5558.19, 0.09008972999999999],
#  [1509515220, 5558.18, 5558.19, 5558.19, 5558.19, 1.91]]

# %%
def get_intraday_rates(product_name):
    data = public_client.get_product_historic_rates(product_name)
    df = pd.DataFrame(data)
    df = df.rename(index=str, columns={0: 'time', 1: 'low', 2:'high', 3: 'open', 4:'close', 5: 'volume'})
    df['time'] = pd.to_datetime(df['time'],unit='s').dt.time
    df=df.set_index('time')
    return df.sort_index()

# %%
eth=get_intraday_rates('ETH-EUR')
ltc=get_intraday_rates('LTC-EUR')

# %%
from sklearn.metrics.pairwise import pairwise_distances

# %%
sim_mat = pairwise_distances(eth, ltc, metric='cosine', n_jobs=-1)

# %%
sim_mat
# Out:
# array([[  1.42253512e-01,   3.98315236e-03,   1.11513141e-07, ...,
#           1.14327589e-01,   1.24919211e-03,   1.15797346e-01],
#        [  1.38191928e-01,   3.30546116e-03,   3.54991642e-05, ...,
#           1.10662600e-01,   8.83891092e-04,   1.12110152e-01],
#        [  1.42614623e-01,   4.04599660e-03,   2.64033551e-08, ...,
#           1.14653778e-01,   1.28447086e-03,   1.16125491e-01],
#        ...,
#        [  1.42599766e-01,   4.04340284e-03,   2.01863311e-08, ...,
#           1.14640357e-01,   1.28301054e-03,   1.16111990e-01],
#        [  1.36562078e-01,   3.04887584e-03,   6.78386439e-05, ...,
#           1.09193937e-01,   7.53872462e-04,   1.10632443e-01],
#        [  1.42433049e-01,   4.01435631e-03,   7.74884035e-09, ...,
#           1.14489814e-01,   1.26663169e-03,   1.15960497e-01]])

# %%
data = pd.read_csv('/home/rkopeinig/Downloads/btc-eur-max.csv')
data = data.set_index('snapped_at')

# %%
# Import dependencies
import os, quandl, pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm

# Firstly: Get data from Quandl
# What is Quandl? It is a marketplace for financial, economic and alternative data 
# delivered in modern formats for today's analysts, including Python.

def get_data(quandl_id):
    '''Download and cache Quandl dataseries'''
    cache_path = '{}.pkl'.format(quandl_id).replace('/','-')
    print cache_path
    try:
        f = open(cache_path, 'rb')
        df = pickle.load(f)   
        print('Loaded {} from cache'.format(quandl_id))
    except (OSError, IOError) as e:
        print('Downloading {} from Quandl'.format(quandl_id))
        df = quandl.get(quandl_id, returns="pandas")
        df.to_pickle(cache_path)
        print('Cached {} at {}'.format(quandl_id, cache_path))
    return df

# Get Bitcoin Data
data = get_data('GDAX/EUR')
data = data['2017-09':'2017-09']
data = data.drop('Volume', axis=1)
# Out:
# GDAX-EUR.pkl
# Loaded GDAX/EUR from cache

# %%
def by_weekday(data):
    df = data.groupby(data.index.dayofweek).mean()
    df.index = ['Mon', 'Tues', 'Wed', 'Thurs', 'Fri', 'Sat', 'Sun']
    return df

# %%
_data = by_weekday(data)
_data.plot(style=[':', '--', '-']);
plt.show()

# %%
#https://github.com/g07kore/PythonDataScienceHandbook/blob/master/notebooks/03.11-Working-with-Time-Series.ipynb

# %%
historic['low'].plot()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-f5e4a94770ed> in <module>()
# ----> 1 historic['low'].plot()
#       2 plt.show()
#
# NameError: name 'historic' is not defined

# %%
data = get_data('GDAX/EUR')
data = data['2017-09':'2017-09']
# Out:
# GDAX-EUR.pkl
# Loaded GDAX/EUR from cache

# %%
data['Volume'].plot()
plt.show()

# %%
data['High'].plot()
plt.show()

# %%
t = 3600*10

# %%
t
# Out:
# 36000

# %%
#1hour = 3600 seconds
public_client.get_product_ticker('ETH-EUR')
# Out:
# {u'ask': u'265.71',
#  u'bid': u'265.7',
#  u'price': u'265.71000000',
#  u'size': u'0.37541162',
#  u'time': u'2017-10-31T11:09:50.626000Z',
#  u'trade_id': 703906,
#  u'volume': u'2461.41620642'}

# %%
quandl.get("WPOV/AUT_SI_POV_NOP2")
# Out:
#                Value
# Date
# 1987-12-31  0.000000
# 1994-12-31  0.053172
# 1995-12-31  0.079483
# 1997-12-31  0.027091
# 2000-12-31  0.032046
# 2004-12-31  0.027785

# %%
# expects Pandas.Series
data = get_data('GDAX/EUR')
data = data['2016']
# Out:
# GDAX-EUR.pkl
# Loaded GDAX/EUR from cache

# %%
rolling = data['Volume'].rolling(36, center=True)

data_ = pd.DataFrame({'input': data['Volume'],
                     'one-year rolling_mean': rolling.mean(),
                     'one-year rolling_std': rolling.std()})
ax = data_.plot(style=['-', '--', ':'])
ax.lines[0].set_alpha(data['Volume'].max())
plt.show()

# %%
# Drop any rows with null values
data = get_data('GDAX/EUR')
data.dropna(axis=0, how='any', inplace=True)
column_names = ['Open', 'High', 'Low', 'Volume']
X = data[column_names]
y = data['Volume']

model = LinearRegression(fit_intercept=True)
model.fit(X, y)
data['predicted'] = model.predict(X)


data[['Open', 'predicted']].plot(alpha=0.5);
plt.show()
# Out:
# GDAX-EUR.pkl
# Loaded GDAX/EUR from cache

# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA

data = get_data('GDAX/EUR')
#del data['Volume']
# Out:
# GDAX-EUR.pkl
# Loaded GDAX/EUR from cache

# %%
def principal_component_analysis(df):
    return  pd.DataFrame(pca.transform(df), columns=['PCA of '+ i for i in data], index=df.index)

# %%
df = principal_component_analysis(data)
#df.plot()
#plt.show()
del df['PCA of Volume']
del df['PCA of Low']

# %%
df.plot()
plt.show()

# %%
del data['Volume']
del data['Low']
data.plot()
plt.show()

# %%
from pylab import rcParams
data = get_data('GDAX/EUR')
# CHIRPS Time-Series seasonal decomposition 
rcParams['figure.figsize'] = 8, 6
dec_data = sm.tsa.seasonal_decompose(data['Volume'], model='additive', freq=30)
dec_data.plot()
plt.show()
# Out:
# GDAX-EUR.pkl
# Loaded GDAX/EUR from cache

# %%
# Mann-Kendall test
def mk_test(x, alpha = 0.05):  
    #import dependencies for Mann-Kendall
    import numpy as np  
    from scipy.stats import norm, mstats
    #alpha: significance level (0.05 default)
    #trend: tells the trend (increasing, decreasing or no trend)
    #h: True (if trend is present) or False (if trend is absence)
    #p: p value of the significance test
    #z: normalized test statistics 
    
    n = len(x)

    s = 0
    for k in range(n-1):
        for j in range(k+1,n):
            s += np.sign(x[j] - x[k])

    unique_x = np.unique(x)
    g = len(unique_x)

    if n == g: # no tie
        var_s = (n*(n-1)*(2*n+5))/18
    else: # some ties in data
        tp = np.zeros(unique_x.shape)
        for i in range(len(unique_x)):
            tp[i] = sum(unique_x[i] == x)
        var_s = (n*(n-1)*(2*n+5) + np.sum(tp*(tp-1)*(2*tp+5)))/18

    if s>0:
        z = (s - 1)/np.sqrt(var_s)
    elif s == 0:
            z = 0
    elif s<0:
        z = (s + 1)/np.sqrt(var_s)

    p = 2*(1-norm.cdf(abs(z))) # two tail test
    h = abs(z) > norm.ppf(1-alpha/2) 

    if (z<0) and h:
        trend = 'decreasing'
    elif (z>0) and h:
        trend = 'increasing'
    else:
        trend = 'no trend'
    return trend, h, p, z

# %%
trend = dec_data.trend['2016-11':'2016-12']
test_trend,h,p,z = mk_test(trend,alpha=0.05)  
print test_trend, h  
print z, p
# Out:
# increasing True
# 11.282631198 0.0

# %%
alpha = 0.05
dec_data = sm.tsa.seasonal_decompose(data['Open'], model='additive', freq=30)
x = dec_data.trend['2015']

# %%
n = len(x)

# calculate S 
s = 0
for k in range(n-1):
    for j in range(k+1,n):
        s += np.sign(x[j] - x[k])
print s
# calculate the unique data
unique_x = np.unique(x)
g = len(unique_x)

# calculate the var(s)
if n == g: # there is no tie
    var_s = (n*(n-1)*(2*n+5))/18
else: # there are some ties in data
    tp = np.zeros(unique_x.shape)
    for i in range(len(unique_x)):
        tp[i] = sum(unique_x[i] == x)
    var_s = (n*(n-1)*(2*n+5) + np.sum(tp*(tp-1)*(2*tp+5)))/18

print s
#if s>0:
#    z = (s - 1)/np.sqrt(var_s)
#elif s == 0:
#    z = 0
#elif s<0:
#    z = (s + 1)/np.sqrt(var_s)

# calculate the p_value
#p = 2*(1-norm.cdf(abs(z))) # two tail test
#h = abs(z) > norm.ppf(1-alpha/2) 

#if (z<0) and h:
#    trend = 'decreasing'
#elif (z>0) and h:
#    trend = 'increasing'
#else:
#    trend = 'no trend'
# Out:
# nan
# nan

# %%
def moving_average(data, window_size):
    #data (pandas.Series): independent variable
    window = np.ones(int(window_size))/float(window_size)
    return np.convolve(data, window, 'same')

# %%
moving_average(data['Low'], 36)
# Out:
# array([  106.01944444,   111.83111111,   117.69916667,   123.59111111,
#          129.64666667,   135.67833333,   141.75638889,   147.75638889,
#          153.79666667,   159.83722222,   165.85388889,   171.84833333,
#          177.77722222,   183.61555556,   189.30777778,   194.94055556,
#          200.5525    ,   206.11527778,   211.75083333,   211.54138889,
#          211.32055556,   210.9725    ,   210.63166667,   210.25166667,
#          210.28055556,   210.07305556,   209.77416667,   209.54361111,
#          209.36944444,   209.54222222,   209.64583333,   209.93944444,
#          210.1825    ,   210.40222222,   210.59416667,   210.87888889,
#          211.15194444,   211.30138889,   211.44638889,   211.60027778,
#          211.77027778,   212.03888889,   212.34      ,   212.92388889,
#          213.39472222,   213.74305556,   214.15138889,   214.63333333,
#          215.18583333,   216.15333333,   217.2225    ,   218.39972222,
#          219.56666667,   221.16138889,   222.86861111,   225.01305556,
#          226.77222222,   228.41666667,   230.0575    ,   231.57583333,
#          233.09722222,   234.55333333,   235.90722222,   237.31972222,
#          238.53833333,   239.37972222,   240.26444444,   241.46583333,
#          242.78      ,   244.18944444,   245.61166667,   246.98694444,
#          248.27388889,   249.63      ,   250.87444444,   251.97777778,
#          252.92055556,   253.77305556,   254.65444444,   255.24055556,
#          255.8175    ,   256.54027778,   256.92444444,   257.245     ,
#          257.49472222,   257.58444444,   257.59222222,   257.50305556,
#          257.48      ,   257.02555556,   256.25527778,   254.99638889,
#          254.00305556,   252.52055556,   251.06666667,   249.62666667,
#          248.06861111,   246.55388889,   244.59305556,   242.87      ,
#          241.36583333,   239.77916667,   238.53805556,   236.97805556,
#          235.2875    ,   233.61      ,   231.87722222,   230.1525    ,
#          228.44361111,   226.87638889,   225.49083333,   224.34027778,
#          223.15055556,   222.065     ,   220.74      ,   219.50083333,
#          218.39472222,   217.16444444,   216.09361111,   215.03944444,
#          214.04111111,   212.85666667,   211.83222222,   210.90861111,
#          209.92472222,   208.96972222,   208.04916667,   207.2725    ,
#               (124, 1348.4987953899999),
#               (143, 1808.0030175500001),
#               (145, 1204.6335264700001),
#               (149, 1122.8298846800001),
#               (150, 1181.4899539400001),
#               (182, 7552.0932050700003),
#               (186, 1560.98619368),
#               (223, 1306.4607959800001),
#               (224, 2658.5209651800001),
#               (226, 2631.4250486999999),
#               (231, 2475.48327655),
#               (238, 1347.6126058899999),
#               (258, 2522.1944881700001),
#               (259, 1754.9477672200001),
#               (263, 1397.4864809200001),
#               (308, 1352.84219927),
#               (313, 3087.9887839200001),
#               (397, 1640.0267580499999),
#               (406, 1437.15622992),
#               (415, 1775.7597059499999),
#               (417, 1346.47346773),
#               (418, 1754.78887682),
#               (455, 1167.1512490499999),
#               (551, 1152.9075934800001),
#               (580, 1249.45968057),
#               (587, 1628.82551487),
#               (603, 279.37821509999998),
#               (608, 2653.04428504),
#               (614, 1924.01884094),
#               (615, 1701.6556014299999),
#               (643, 1704.48744566),
#               (666, 291.16645712000002),
#               (671, 2478.12703078),
#               (676, 1877.3211209200001),
#               (677, 2126.5353454900001),
#               (678, 2484.9100694200001),
#               (683, 1740.4369185600001),
#               (723, 2747.6830393599998),
#               (724, 1829.53633059),
#               (728, 2195.5626475499998),
#               (733, 698.75269274000004),
#               (734, 1167.6292533799999),
#               (737, 1053.15870819),
#               (739, 1097.55651315),
#               (740, 1175.43610704),
#               (741, 4685.5756018000002),
#               (744, 3770.0788506899999),
#               (745, 3424.5968710900001),
#               (746, 3226.1498783900001),
#               (750, 2917.9953202000002),
#               (752, 1208.53459877),
#               (753, 1260.77071497),
#               (754, 942.31500328000004),
#               (755, 1316.7104107299999),
#               (756, 2757.1753511699999),
#               (759, 1451.1126764400001),
#               (760, 1114.16532704),
#               (762, 2699.17083585),
#               (764, 2502.8073321400002),
#               (765, 4737.5172240700003),
#               (766, 2334.2526765799998),
#               (767, 964.83735831000001),
#               (768, 899.67731031000005),
#               (773, 719.31352980999998),
#               (774, 852.08171209),
#               (775, 809.50124900000003),
#               (777, 2097.6581545600002),
#               (779, 875.78117727999995),
#               (782, 739.28853253),
#               (786, 747.76200008000001),
#               (788, 594.18243113000005),
#               (789, 402.70871277999998),
#               (791, 1945.10102869),
#               (796, 2115.6440273100002),
#               (797, 2073.0909102700002),
#               (798, 2311.9740904599998),
#               (799, 1953.57399977),
#               (800, 3152.8621006200001),
#               (801, 2461.2109618),
#               (805, 2147.7875641199998),
#               (807, 962.05672575000006),
#               (809, 594.97955473000002),
#               (810, 164.71901034000001),
#               (811, 1069.6866633),
#               (814, 869.25752144),
#               (815, 1111.80435659),
#               (816, 2320.0449534099998),
#               (817, 842.95209780000005),
#               (824, 2153.39353084),
#               (825, 2813.9247154899999),
#               (826, 4136.8042936800002),
#               (828, 2594.0788131600002),
#               (830, 1128.9500228700001),
#               (831, 795.91959392000001),
#               (833, 2486.0183369400002),
#               (835, 1061.11950501),
#               (837, 563.07891360999997),
#               (838, 604.81380969999998),
#               (839, 1221.79952316),
#               (841, 1591.02550015),
#               (845, 1017.3749926),
#               (846, 3452.85629948),
#               (848, 3136.6786874300001),
#               (850, 2601.85543809),
#               (851, 918.60353521000002),
#               (852, 1010.58244182),
#               (853, 983.31453966000004),
#               (855, 3295.5627275299998),
#               (856, 4701.7460616199996),
#               (857, 7651.7041157800004),
#               (858, 2810.2179885999999),
#               (860, 2824.7405861399998),
#               (862, 913.20942445000003),
#               (863, 2219.5847416500001),
#               (866, 630.05316560999995),
#               (869, 2066.1026407899999)]),
#  'standard_deviation': 558.483}

# %%
def explain_anomalies_rolling_std(y, window_size, sigma=1.0):
    import collections
    from itertools import izip, count
    avg = moving_average(y, window_size)
    avg_list = avg.tolist()
    residual = y - avg
    
    testing_std = pd.rolling_std(residual, window_size)
    testing_std_as_df = pd.DataFrame(testing_std)
    rolling_std = testing_std_as_df.replace(np.nan,
                                  testing_std_as_df.ix[window_size - 1]).round(3).iloc[:,0].tolist()
    std = np.std(residual)
    return {'stationary standard_deviation': round(std, 3),
            'anomalies_dict': collections.OrderedDict([(index, y_i)
                                                       for index, y_i, avg_i, rs_i in izip(count(),
                                                                                           y, avg_list, rolling_std)
              if (y_i > avg_i + (sigma * rs_i)) | (y_i < avg_i - (sigma * rs_i))])}

# %%
explain_anomalies_rolling_std(data['Volume'], 36)
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:12: FutureWarning: pd.rolling_std is deprecated for Series and will be removed in a future version, replace with
# 	Series.rolling(window=36,center=False).std()
# {'anomalies_dict': OrderedDict([(2, 194.59139999999999),
#               (3, 303.47829999999999),
#               (4, 248.27297003000001),
#               (5, 235.076864),
#               (6, 202.60840521),
#               (14, 46.710000000000001),
#               (24, 292.63188000000002),
#               (25, 207.94042442),
#               (28, 26.958656000000001),
#               (29, 63.252229999999997),
#               (32, 56.732289999999999),
#               (36, 27.739999999999998),
#               (39, 94.494620100000006),
#               (42, 61.489227),
#               (43, 62.308113400000003),
#               (44, 285.94869181000001),
#               (45, 398.53610610999999),
#               (46, 435.71454720000003),
#               (47, 330.43933500000003),
#               (50, 96.836370000000002),
#               (53, 166.29788199999999),
#               (54, 199.01715949999999),
#               (55, 162.501676),
#               (57, 229.17723344000001),
#               (59, 506.50354240000001),
#               (60, 604.86566500000004),
#               (62, 257.47116),
#               (63, 127.633145),
#               (66, 541.1201873),
#               (67, 508.90927008),
#               (68, 590.70353299999999),
#               (69, 803.61382209999999),
#               (71, 797.02681227000005),
#               (72, 838.56343830000003),
#               (84, 140.47079449),
#               (85, 161.18361229999999),
#               (87, 126.96956717),
#               (92, 88.641078399999998),
#               (94, 620.08870875000002),
#               (99, 140.77756575000001),
#               (106, 136.42095857999999),
#               (107, 194.85626855000001),
#               (108, 297.13738065000001),
#               (110, 677.02593564999995),
#               (113, 718.81126972000004),
#               (114, 954.63845178999998),
#               (115, 893.53187598),
#               (116, 864.21790805000001),
#               (118, 760.42280176999998),
#               (119, 219.32169257000001),
#               (120, 199.59420173999999),
#               (122, 1468.3067814799999),
#               (124, 1348.4987953899999),
#               (131, 939.28070646000003),
#               (134, 224.68019136999999),
#               (139, 227.82013108999999),
#               (140, 219.89804076999999),
#               (143, 1808.0030175500001),
#               (145, 1204.6335264700001),
#               (149, 1122.8298846800001),
#               (150, 1181.4899539400001),
#               (168, 1069.81724396),
#               (171, 138.17976221000001),
#               (172, 128.89839169000001),
#               (174, 79.214093570000003),
#               (177, 35.897501669999997),
#               (180, 183.96522229000001),
#               (182, 7552.0932050700003),
#               (218, 173.12760521999999),
#               (219, 50.012680510000003),
#               (220, 11.02788552),
#               (221, 946.76154795000002),
#               (222, 344.28725790999999),
#               (223, 1306.4607959800001),
#               (224, 2658.5209651800001),
#               (226, 2631.4250486999999),
#               (231, 2475.48327655),
#               (258, 2522.1944881700001),
#               (259, 1754.9477672200001),
#               (263, 1397.4864809200001),
#               (295, 1106.58884053),
#               (301, 299.52772184999998),
#               (302, 451.17185174999997),
#               (306, 1026.36960752),
#               (308, 1352.84219927),
#               (313, 3087.9887839200001),
#               (320, 1150.0290606799999),
#               (350, 331.23302589000002),
#               (351, 354.58945688),
#               (354, 969.87200258999997),
#               (355, 868.77069599000004),
#               (360, 1049.6617449400001),
#               (361, 755.20260038000004),
#               (364, 262.12673398999999),
#               (366, 798.77041942999995),
#               (370, 145.07612850999999),
#               (371, 171.00063827),
#               (372, 227.94705562999999),
#               (374, 187.8236464),
#               (378, 284.49200979),
#               (384, 296.05056108000002),
#               (390, 1170.0391432700001),
#               (391, 1146.9404040700001),
#               (397, 1640.0267580499999),
#               (399, 474.87194891000001),
#               (402, 510.01395635),
#               (403, 491.34645195000002),
#               (404, 460.01826650999999),
#               (405, 411.26172119),
#               (406, 1437.15622992),
#               (407, 1286.13572755),
#               (411, 1089.77238865),
#               (413, 306.71427927000002),
#               (415, 1775.7597059499999),
#               (416, 1168.12120099),
#               (417, 1346.47346773),
#               (418, 1754.78887682),
#               (454, 871.86965123000004),
#               (455, 1167.1512490499999),
#               (456, 757.36953843000003),
#               (472, 11.08),
#               (478, 4.0499999999999998),
#               (489, 536.55211455999995),
#               (498, 170.11833684999999),
#               (499, 124.17254106),
#               (502, 440.01656838000002),
#               (505, 178.83034425),
#               (506, 167.69035969000001),
#               (513, 196.65737621),
#               (514, 418.24764451999999),
#               (515, 471.90016997999999),
#               (518, 457.82938572),
#               (519, 168.12528903),
#               (520, 176.43036401000001),
#               (521, 474.71362252),
#               (522, 637.99283419000005),
#               (527, 148.42501551000001),
#               (533, 254.49778605),
#               (534, 225.03808699000001),
#               (537, 536.46249052999997),
#               (538, 519.28946651000001),
#               (545, 827.61277787999995),
#               (547, 215.74418046),
#               (548, 195.91364804),
#               (551, 1152.9075934800001),
#               (554, 188.66710942),
#               (558, 763.07978705999994),
#               (561, 215.8645047),
#               (568, 197.91272484000001),
#               (569, 201.92206726000001),
#               (576, 246.23265105999999),
#               (580, 1249.45968057),
#               (582, 211.12959591000001),
#               (583, 203.86456702000001),
#               (587, 1628.82551487),
#               (589, 325.19066565000003),
#               (590, 200.62222703),
#               (595, 1219.44908713),
#               (596, 397.60497492000002),
#               (598, 340.21991224999999),
#               (600, 1124.62641334),
#               (603, 279.37821509999998),
#               (604, 477.68220990999998),
#               (607, 1295.1559295100001),
#               (608, 2653.04428504),
#               (609, 1308.6214792000001),
#               (614, 1924.01884094),
#               (615, 1701.6556014299999),
#               (643, 1704.48744566),
#               (653, 390.76989814000001),
#               (658, 1290.3838061399999),
#               (660, 320.66462239999998),
#               (665, 512.42452720999995),
#               (666, 291.16645712000002),
#               (667, 616.23194009999997),
#               (669, 1456.86595113),
#               (671, 2478.12703078),
#               (676, 1877.3211209200001),
#               (677, 2126.5353454900001),
#               (678, 2484.9100694200001),
#               (683, 1740.4369185600001),
#               (705, 230.01309773),
#               (706, 301.84004454000001),
#               (711, 386.76399944999997),
#               (717, 1386.20960117),
#               (719, 626.05601487000001),
#               (720, 1313.03530746),
#               (721, 1445.00618349),
#               (723, 2747.6830393599998),
#               (724, 1829.53633059),
#               (728, 2195.5626475499998),
#               (732, 1133.15214324),
#               (733, 698.75269274000004),
#               (734, 1167.6292533799999),
#               (737, 1053.15870819),
#               (738, 1281.39223825),
#               (739, 1097.55651315),
#               (740, 1175.43610704),
#               (741, 4685.5756018000002),
#               (744, 3770.0788506899999),
#               (745, 3424.5968710900001),
#               (746, 3226.1498783900001),
#               (750, 2917.9953202000002),
#               (754, 942.31500328000004),
#               (765, 4737.5172240700003),
#               (788, 594.18243113000005),
#               (789, 402.70871277999998),
#               (796, 2115.6440273100002),
#               (797, 2073.0909102700002),
#               (798, 2311.9740904599998),
#               (800, 3152.8621006200001),
#               (801, 2461.2109618),
#               (805, 2147.7875641199998),
#               (809, 594.97955473000002),
#               (810, 164.71901034000001),
#               (814, 869.25752144),
#               (817, 842.95209780000005),
#               (825, 2813.9247154899999),
#               (826, 4136.8042936800002),
#               (828, 2594.0788131600002),
#               (831, 795.91959392000001),
#               (837, 563.07891360999997),
#               (838, 604.81380969999998),
#               (845, 1017.3749926),
#               (846, 3452.85629948),
#               (848, 3136.6786874300001),
#               (851, 918.60353521000002),
#               (852, 1010.58244182),
#               (853, 983.31453966000004),
#               (855, 3295.5627275299998),
#               (856, 4701.7460616199996),
#               (857, 7651.7041157800004)]),
#  'stationary standard_deviation': 558.483}

# %%
data.corr(method='pearson')
# Out:
#             Open      High       Low    Volume
# Open    1.000000  0.995631  0.998330  0.607493
# High    0.995631  1.000000  0.994990  0.622841
# Low     0.998330  0.994990  1.000000  0.587609
# Volume  0.607493  0.622841  0.587609  1.000000

# %%
import pandas, numpy as np
ewma = pandas.stats.moments.ewma

# make a hat function, and add noise
x=eth['low']

# take EWMA in both directions with a smaller span term
fwd = ewma( x, span=15 )          # take EWMA in fwd direction
bwd = ewma( x[::-1], span=15 )    # take EWMA in bwd direction
c = np.vstack(( fwd, bwd[::-1] )) # lump fwd and bwd together
c = np.mean( c, axis=0 )          # average  

# regular EWMA, with bias against trend
pd.Series(x).plot()
plt.show()
# "corrected" (?) EWMA
pd.Series(c, index=eth.index).plot()
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:8: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(ignore_na=False,span=15,min_periods=0,adjust=True).mean()
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:9: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(ignore_na=False,span=15,min_periods=0,adjust=True).mean()

# %%
eth['low'].plot()
plt.show()
